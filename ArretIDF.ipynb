# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
rawstif = pd.read_csv('../../../Downloads/referentiel-arret-tc-idf.csv',sep=';')
rawstif.head(2)
# Out:
#    ZDEr_ID_REF_A                      ZDEr_NOM  ZDEr_ID_TYPE_ARRET  \
# 0           7895  LA DEFENSE-METRO-RER-TRAMWAY                   5
# 1          41411         RIS ORANGIS DAUMESNIL                   5
#
#   ZDEr_LIBELLE_TYPE_ARRET                ZDEr_X_Y  ZDLr_ID_REF_A  \
# 0            Arrêt de bus        644081.4,6865998          43536
# 1            Arrêt de bus  656814.001,6839263.097          43543
#
#                     ZDLr_NOM  ZDLr_ID_TYPE_ARRET ZDLr_LIBELLE_TYPE_ARRET  \
# 0  La Défense (Grande Arche)                   1             Gare ferrée
# 1    Daumesnil / La Fontaine                   5            Arrêt de bus
#
#    LDA_ID_REF_A                    LDA_NOM  LDA_ID_TYPE_ARRET  \
# 0         71517  La Défense (Grande Arche)                  1
# 1         73681    Daumesnil / La Fontaine                  5
#
#   LDA_LIBELLE_TYPE_ARRET
# 0            Gare ferrée
# 1           Arrêt de bus

# %%
rawstif.describe()
# Out:
#        ZDEr_ID_REF_A  ZDEr_ID_TYPE_ARRET  ZDLr_ID_REF_A  ZDLr_ID_TYPE_ARRET  \
# count   42091.000000        42091.000000   42091.000000        42091.000000
# mean    60430.345418            4.924711   63374.975696            4.599368
# std    117361.169347            0.556446   70385.329553            1.190494
# min      2125.000000            1.000000   42135.000000            1.000000
# 25%     13148.500000            5.000000   44595.000000            5.000000
# 50%     24165.000000            5.000000   49095.000000            5.000000
# 75%     35114.500000            5.000000   54490.000000            5.000000
# max    420444.000000            6.000000  420447.000000            6.000000
#
#         LDA_ID_REF_A  LDA_ID_TYPE_ARRET
# count   42091.000000       42091.000000
# mean    80911.637500           4.511154
# std     67999.798122           1.297562
# min     59388.000000           1.000000
# 25%     63651.000000           5.000000
# 50%     67562.000000           5.000000
# 75%     71358.500000           5.000000
# max    420437.000000           6.000000

# %%
rawstif['ZDLr_LIBELLE_TYPE_ARRET'].unique()
# Out:
# array(['Gare ferrée', 'Arrêt de bus', 'Station de métro', 'Arrêt de tram'], dtype=object)

# %%
rawstif['X'], rawstif['Y'] = zip(*rawstif['ZDEr_X_Y'].apply(lambda x: x.split(',', 1)))
rawstif.head(2)
# Out:
#    ZDEr_ID_REF_A                      ZDEr_NOM  ZDEr_ID_TYPE_ARRET  \
# 0           7895  LA DEFENSE-METRO-RER-TRAMWAY                   5
# 1          41411         RIS ORANGIS DAUMESNIL                   5
#
#   ZDEr_LIBELLE_TYPE_ARRET                ZDEr_X_Y  ZDLr_ID_REF_A  \
# 0            Arrêt de bus        644081.4,6865998          43536
# 1            Arrêt de bus  656814.001,6839263.097          43543
#
#                     ZDLr_NOM  ZDLr_ID_TYPE_ARRET ZDLr_LIBELLE_TYPE_ARRET  \
# 0  La Défense (Grande Arche)                   1             Gare ferrée
# 1    Daumesnil / La Fontaine                   5            Arrêt de bus
#
#    LDA_ID_REF_A                    LDA_NOM  LDA_ID_TYPE_ARRET  \
# 0         71517  La Défense (Grande Arche)                  1
# 1         73681    Daumesnil / La Fontaine                  5
#
#   LDA_LIBELLE_TYPE_ARRET           X            Y
# 0            Gare ferrée    644081.4      6865998
# 1           Arrêt de bus  656814.001  6839263.097

# %%
rawstif.dtypes
# Out:
# ZDEr_ID_REF_A               int64
# ZDEr_NOM                   object
# ZDEr_ID_TYPE_ARRET          int64
# ZDEr_LIBELLE_TYPE_ARRET    object
# ZDEr_X_Y                   object
# ZDLr_ID_REF_A               int64
# ZDLr_NOM                   object
# ZDLr_ID_TYPE_ARRET          int64
# ZDLr_LIBELLE_TYPE_ARRET    object
# LDA_ID_REF_A                int64
# LDA_NOM                    object
# LDA_ID_TYPE_ARRET           int64
# LDA_LIBELLE_TYPE_ARRET     object
# X                          object
# Y                          object
# dtype: object

# %%
rawstif['X'] = pd.to_numeric(rawstif['X'])
rawstif['Y'] = pd.to_numeric(rawstif['Y'])
rawstif.dtypes
# Out:
# ZDEr_ID_REF_A                int64
# ZDEr_NOM                    object
# ZDEr_ID_TYPE_ARRET           int64
# ZDEr_LIBELLE_TYPE_ARRET     object
# ZDEr_X_Y                    object
# ZDLr_ID_REF_A                int64
# ZDLr_NOM                    object
# ZDLr_ID_TYPE_ARRET           int64
# ZDLr_LIBELLE_TYPE_ARRET     object
# LDA_ID_REF_A                 int64
# LDA_NOM                     object
# LDA_ID_TYPE_ARRET            int64
# LDA_LIBELLE_TYPE_ARRET      object
# X                          float64
# Y                          float64
# dtype: object

# %%
rawstif.head(2)
# Out:
#    ZDEr_ID_REF_A                      ZDEr_NOM  ZDEr_ID_TYPE_ARRET  \
# 0           7895  LA DEFENSE-METRO-RER-TRAMWAY                   5
# 1          41411         RIS ORANGIS DAUMESNIL                   5
#
#   ZDEr_LIBELLE_TYPE_ARRET                ZDEr_X_Y  ZDLr_ID_REF_A  \
# 0            Arrêt de bus        644081.4,6865998          43536
# 1            Arrêt de bus  656814.001,6839263.097          43543
#
#                     ZDLr_NOM  ZDLr_ID_TYPE_ARRET ZDLr_LIBELLE_TYPE_ARRET  \
# 0  La Défense (Grande Arche)                   1             Gare ferrée
# 1    Daumesnil / La Fontaine                   5            Arrêt de bus
#
#    LDA_ID_REF_A                    LDA_NOM  LDA_ID_TYPE_ARRET  \
# 0         71517  La Défense (Grande Arche)                  1
# 1         73681    Daumesnil / La Fontaine                  5
#
#   LDA_LIBELLE_TYPE_ARRET           X            Y
# 0            Gare ferrée  644081.400  6865998.000
# 1           Arrêt de bus  656814.001  6839263.097

# %%
D=rawstif['LDA_LIBELLE_TYPE_ARRET'].tolist()
ColorsCode = {'Gare ferrée' : 'r', 'Arrêt de bus' :'b', 'Station de métro' : 'g', 'Arrêt de tram' : 'k'}
MarkerCode = {'Gare ferrée' : "sr", 'Arrêt de bus' : ".b", 'Station de métro' : "vk", 'Arrêt de tram' : "^k"}
SizeCode = {'Gare ferrée' : '2', 'Arrêt de bus' :'0.01', 'Station de métro' : '1', 'Arrêt de tram' : '1'}
M = [MarkerCode[arret] for arret in D]
S = [float(SizeCode[arret]) for arret in D]
D = [ColorsCode[arret] for arret in D]


type(M[10])
(M[3])
# Out:
# 'vk'

# %%
plt.figure(figsize=(12,12)) 
plt.scatter(rawstif['X'], rawstif['Y'], s=S, color=D )
plt.axis('off')
plt.show()
# Out:
# C:\Users\Bricolo\Anaconda3\envs\lty\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.figure(figsize=(12,12)) 
plt.scatter(rawstif['X'], rawstif['Y'], s=S, color=D)
v=[625000.0, 700000.0, 6830000.0, 6880000.0]
plt.axis('equal')
plt.axis(v)
plt.axis('off')
plt.show()
# Out:
# C:\Users\Bricolo\Anaconda3\envs\lty\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
